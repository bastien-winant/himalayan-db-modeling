# %% [markdown]
# # Members Dataset EDA

# %%
import sys
from pathlib import Path

import pandas as pd

# %%
# Add parent directory to Python path
sys.path.append(str(Path().resolve().parent))

# %%
from src.utils.preprocessing import *

# %%
file_path = str(Path().resolve().parent / "data/raw/members.DBF")
df = read_dbf(file_path)

# %%
df.head()
# Out:
#        expid membid peakid myear  mseason        fname      lname sex  age  \
# 0  AMAD78301     01   AMAD  1978        3  Jean Robert  Clemenson   M    0
# 1  AMAD78301     02   AMAD  1978        3      Bernard     Dufour   M    0
# 2  AMAD78301     03   AMAD  1978        3     Philippe     Gerard   M    0
# 3  AMAD78301     04   AMAD  1978        3         Eric   Lasserre   M    0
# 4  AMAD78301     05   AMAD  1978        3          Guy     Peters   M    0
#
#   birthdate  ... membermemo  necrology msmtbid msmtterm hcn  mchksum  \
# 0      None  ...       None       None       1        4   0  2426937
# 1      None  ...       None       None       1        4   0  2426501
# 2      None  ...       None       None       1        4   0  2431569
# 3      None  ...       None       None       1        4   0  2426809
# 4      None  ...       None       None       1        4   0  2429215
#
#    msmtnote1  msmtnote2  msmtnote3  deathrte
# 0        NaN        NaN        NaN       NaN
# ...

# %%
df.describe()
# Out:
#             mseason      age       calcage    mperhighpt       mroute1  \
# count  90857.000000  90857.0  90857.000000  90857.000000  90857.000000
# mean       2.048626      0.0     36.344938   5413.223791      0.689864
# std        1.031869      0.0     12.665989   3484.984600      0.489578
# min        1.000000      0.0      0.000000      0.000000      0.000000
# 25%        1.000000      0.0     29.000000      0.000000      0.000000
# 50%        3.000000      0.0     36.000000   6814.000000      1.000000
# 75%        3.000000      0.0     44.000000   8167.000000      1.000000
# max        4.000000      0.0     85.000000   8850.000000      4.000000
#
#             mroute2       mroute3      mascent1     mascent2      mascent3  \
# count  90857.000000  90857.000000  90857.000000  90857.00000  90857.000000
# mean       0.005701      0.000253     13.493754      0.14678      0.002322
# std        0.086706      0.016586     57.347429      6.27679      0.421276
# ...

# %%
df['expid'] = df.expid.str.cat(df.myear, sep="_")

# %%
df.groupby(['expid', 'membid']).expid.apply('count').sort_values(ascending=False)
# Out:
# expid           membid
# YLNG24101_2024  03        1
# ACHN15301_2015  01        1
#                 02        1
#                 03        1
#                 04        1
#                          ..
# ACHN15302_2015  08        1
#                 09        1
#                 10        1
#                 11        1
# ACHN18301_2018  01        1
# Name: expid, Length: 90857, dtype: int64

# %%
df.ams.value_counts()
# Out:
# ams
# False    90695
# True       162
# Name: count, dtype: int64

# %%
df.loc[df.ams].deathtype.value_counts()
# Out:
# deathtype
# 1     115
# 2      22
# 4      15
# 3       5
# 10      3
# 7       1
# 8       1
# Name: count, dtype: int64
